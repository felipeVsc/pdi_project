# %%
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('./bottles/train/train_2.jpg')

plt.imshow(img)

# %%
# Detectção de objetos e pegar o objeto do meio
# Detecção para pegar o nivel dao liquido
# detecção do adesivo
