# %%
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('./bottles/train/train_46.jpg',cv.IMREAD_GRAYSCALE)
(thresh, im_bw) = cv.threshold(img, 128, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
plt.imshow(im_bw,'gray')

total_pixels = im_bw.size

# Conta o número de pixels pretos (0)
black_pixels = total_pixels - cv.countNonZero(im_bw)

# Calcula a porcentagem de pixels pretos
percentage_black_pixels = (black_pixels / total_pixels) * 100

# Exibe a porcentagem
print(f"A porcentagem de pixels pretos na imagem é: {percentage_black_pixels:.2f}%")
median_value = cv.medianBlur(img, 5)[img.shape[0] // 2, img.shape[1] // 2]

print(f"The median pixel value of the grayscale image is: {median_value}")
# Out:
# 42003
# A porcentagem de pixels pretos na imagem é: 41.43%
# The median pixel value of the grayscale image is: 205

# %%
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('./bottles/train/train_46.jpg',cv.IMREAD_GRAYSCALE)
(thresh, im_bw) = cv.threshold(img, 128, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
plt.imshow(im_bw,'gray')

# %%
# Detectção de objetos e pegar o objeto do meio
# Detecção para pegar o nivel dao liquido
# detecção do adesivo

# %%
# bottle_missing

def detect_bottle_missing(src):
    total_pixels = im_bw.size

# Conta o número de pixels pretos (0)
black_pixels = total_pixels - cv.countNonZero(im_bw)

# Calcula a porcentagem de pixels pretos
percentage_black_pixels = (black_pixels / total_pixels) * 100



# Exibe a porcentagem
print(f"A porcentagem de pixels pretos na imagem é: {percentage_black_pixels:.2f}%")

    if percentage_black_pixels>33:
        pass

# %%
# cap missing

import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('./bottles/train/train_18.jpg',cv.IMREAD_GRAYSCALE)
(thresh, im_bw) = cv.threshold(img, 128, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)

new_img = im_bw[0:100]

total_pixels = new_img.size

# Conta o número de pixels pretos (0)
black_pixels = total_pixels - cv.countNonZero(new_img)

# Calcula a porcentagem de pixels pretos
percentage_black_pixels = (black_pixels / total_pixels) * 100

# Exibe a porcentagem
print(f"A porcentagem de pixels pretos na imagem é: {percentage_black_pixels:.2f}%")
median_value = cv.medianBlur(img, 5)[img.shape[0] // 2, img.shape[1] // 2]
plt.imshow(new_img,'gray')
# treshhold de 20 eu acho
# Out:
# A porcentagem de pixels pretos na imagem é: 23.23%

# %%
# label missing

import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('./bottles/train/train_51.jpg',cv.IMREAD_GRAYSCALE)
(thresh, im_bw) = cv.threshold(img, 128, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)

new_img = im_bw[150:,100:260]

total_pixels = new_img.size

# Conta o número de pixels pretos (0)
black_pixels = total_pixels - cv.countNonZero(new_img)

# Calcula a porcentagem de pixels pretos
percentage_black_pixels = (black_pixels / total_pixels) * 100

# Exibe a porcentagem
print(f"A porcentagem de pixels pretos na imagem é: {percentage_black_pixels:.2f}%")
median_value = cv.medianBlur(img, 5)[img.shape[0] // 2, img.shape[1] // 2]
plt.imshow(new_img,'gray')
# label errada vai ser quando isso aqui tiver mt baixo
# bom fazer testes para ver como irá se portar dado o crop feito

# Tem um limite superior e inferior, superior é qnt nao tem mas tem liquido e inferior é quando nao tem a botttle
# Out:
# A porcentagem de pixels pretos na imagem é: 83.15%

# %%
# teste de label missing vendo a quantidade de vermelho

# label missing

import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('./bottles/train/train_61.jpg')
#(thresh, im_bw) = cv.threshold(img, 128, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
def bgr_to_rgb(image_bgr):
    # Use a função cv2.cvtColor para converter de BGR para RGB
    image_rgb = cv.cvtColor(image_bgr, cv.COLOR_BGR2RGB)
    return image_rgb

img = bgr_to_rgb(img)

def contar_pixels_vermelhos(image_rgb):
    # Defina o intervalo de cores vermelhas (em RGB)
    lower_red = np.array([55, 0, 0])   
    upper_red = np.array([255, 0, 0]) 

    # Crie uma máscara para os pixels vermelhos
    mask = cv.inRange(image_rgb, lower_red, upper_red)

    # Conte os pixels vermelhos na máscara
    red_pixel_count = np.count_nonzero(mask)
    
    total_pixels = image_rgb.shape[0] * image_rgb.shape[1]

    # Calcule a porcentagem de pixels vermelhos
    percentage_red = (red_pixel_count / total_pixels) * 100

    return percentage_red

def calcular_porcentagem_vermelho_e_branco(imagem):
    # Converte a imagem para o espaço de cores HSV (Hue, Saturation, Value)
    hsv = cv.cvtColor(imagem, cv.COLOR_BGR2HSV)
    
    # Define os intervalos de cor para o vermelho e o branco
    # Note que esses intervalos podem variar dependendo da iluminação e das condições da imagem
    vermelho_min = np.array([70, 0, 0], dtype=np.uint8)
    vermelho_max = np.array([255, 0, 0], dtype=np.uint8)
    branco_min = np.array([150, 150, 150], dtype=np.uint8)
    branco_max = np.array([255, 255, 255], dtype=np.uint8)
    
    # Crie máscaras para as cores vermelho e branco
    mascara_vermelha = cv.inRange(imagem, vermelho_min, vermelho_max)
    mascara_branca = cv.inRange(imagem, branco_min, branco_max)
    
    
    # Combina as máscaras
    mascara_combinada = cv.bitwise_or(mascara_vermelha, mascara_branca)
    
    # Calcule o número total de pixels na imagem
    total_pixels = imagem.shape[0] * imagem.shape[1]
    
    # Calcule o número de pixels vermelhos e brancos
    pixels_vermelhos_e_brancos = np.count_nonzero(mascara_combinada)
    
    # Calcule a porcentagem de pixels vermelhos e brancos em relação ao total
    porcentagem = (pixels_vermelhos_e_brancos / total_pixels) * 100.0
    
    return porcentagem

#count = contar_pixels_vermelhos(img)
count = calcular_porcentagem_vermelho_e_branco(img)
print(f"A quantidade de pixels vermelhos na imagem é: {count}")

new_img = img[150:,100:260]
plt.imshow(new_img)
# label errada vai ser quando isso aqui tiver mt baixo
# bom fazer testes para ver como irá se portar dado o crop feito

# Tem um limite superior e inferior, superior é qnt nao tem mas tem liquido e inferior é quando nao tem a botttle

# DOESNT WORK IN COLORS
# Out:
# A quantidade de pixels vermelhos na imagem é: 37.55326704545455

# %%
# Essse é do monitor

import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('./bottles/train/train_46.jpg')

bottle_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
bottle_gray = cv.GaussianBlur(bottle_gray, (7, 7), 0)
(T, bottle_threshold) = cv.threshold(bottle_gray, 55, 255, cv.THRESH_BINARY_INV)
black_segment = cv.bitwise_and(img, img, mask=bottle_threshold)
# cv_imshow(black_segment)
plt.imshow(black_segment)
total_pixels = img.shape[0] * img.shape[1]
black_pixels = np.sum(bottle_threshold) // 255
black_percentage = black_pixels / total_pixels
print(f'Percentual de preto: {black_percentage}')
# Out:
# Percentual de preto: 0.10216422032828283

# %%
# analisando white pixels

# label missing

import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('./bottles/train/train_56.jpg',cv.IMREAD_GRAYSCALE)
(thresh, im_bw) = cv.threshold(img, 128, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)

new_img = im_bw[150:,100:260]

total_pixels = new_img.size

# Conta o número de pixels pretos (0)
#black_pixels = total_pixels - cv.countNonZero(new_img)

# Calcula a porcentagem de pixels pretos
percentage_black_pixels = (cv.countNonZero(new_img) / total_pixels) * 100

# Exibe a porcentagem
print(f"A porcentagem de pixels brancos na imagem é: {percentage_black_pixels:.2f}%")
median_value = cv.medianBlur(img, 5)[img.shape[0] // 2, img.shape[1] // 2]
plt.imshow(new_img,'gray')
# label errada vai ser quando isso aqui tiver mt baixo
# bom fazer testes para ver como irá se portar dado o crop feito

# Tem um limite superior e inferior, superior é qnt nao tem mas tem liquido e inferior é quando nao tem a botttle

# como ja vai ter passado pelo missing bottle, é ok
# Out:
# A porcentagem de pixels brancos na imagem é: 58.37%

# %%
# label misplaced. como fazer? só deus sabe xD

import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('./bottles/train/train_19.jpg',cv.IMREAD_GRAYSCALE)
(thresh, im_bw) = cv.threshold(img, 128, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)

new_img = im_bw[150:,100:260]
plt.imshow(new_img,'gray')

# %%
image = cv.imread('./bottles/train/train_11.jpg')
image = image[160:260,100:260]

# Convert the image to grayscale
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

# Apply Gaussian blur to reduce noise and improve line detection
# Threshold the grayscale image to isolate white regions
_, thresholded = cv.threshold(gray, 150, 255, cv.THRESH_BINARY)

# Detect lines using the Hough Line Transform with theta set to np.pi/2
lines = cv.HoughLines(thresholded, 1, np.pi / 2, threshold=100)
print(lines)

# Draw the detected horizontal lines on the original image
if lines is not None:
    for line in lines:
        rho, theta = line[0]
        if np.pi / 4 <= theta <= 3 * np.pi / 4:  # Check if the line is vertical (theta is close to pi/2)
            a = np.cos(theta)
            b = np.sin(theta)
            x0 = a * rho
            y0 = b * rho
            x1 = int(x0 + 1000 * (-b))
            y1 = int(y0 + 1000 * (a))
            x2 = int(x0 - 1000 * (-b))
            y2 = int(y0 - 1000 * (a))
            cv.line(image, (x1, y1), (x2, y2), (0, 0, 255), 2)

plt.imshow(image,'gray')
# Out:
# [[[23.         1.5707964]]]
